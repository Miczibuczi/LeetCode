# %%
# cur_min = (price[i], i)
# ans = [[sum, last_min, last_sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[0, 0, 0]]
        cur_min, long_min = (prices[0], 0), prices[0]
        for i, price in enumerate(prices[1:]):
            if price < cur_min[0]:
                cur_min = (price, i)
                if price < long_min:
                    long_min = price
            else:
                cur_sum = prices[i]-cur_min[0]
                if len(ans) < k and ans[-1][1] != cur_min[1]:
                    ans.append([ans[-1][0]+cur_sum, cur_min, cur_sum])
                for i in range(len(ans)-1, 0, -1):
                    if ans[i][2] < cur_sum:
                        ans[i][0] += cur_sum-ans[i][2]
                        ans[i][1] = cur_min
                        ans[i][2] = cur_sum
                if prices[i] - long_min > ans[0][0]:
                    ans[0] = [prices[i]-long_min, long_min, prices[i]-long_min]
        return ans[-1][0]

# %%
# cur_min = (price[i], i)
# ans = [[sum, last_min, last_sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[0, 0, 0]]
        cur_min, long_min = (prices[0], 0), prices[0]
        for i, price in enumerate(prices):
            print("start" ,i, price, ans)
            if price < cur_min[0]:
                cur_min = (price, i)
                if price < long_min:
                    long_min = price
            else:
                cur_sum = prices[i]-cur_min[0]
                if len(ans) < k and ans[-1][1] != cur_min[1]:
                    ans.append([ans[-1][0]+cur_sum, cur_min[0], cur_sum])
                    cur_min = (price, i)
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][2] < cur_sum:
                        ans[j][0] += cur_sum-ans[j][2]
                        ans[j][1] = cur_min[0]
                        ans[j][2] = cur_sum
                if price - long_min > ans[0][0]:
                    ans[0] = [price-long_min, long_min, price-long_min]
            print("stop", ans)
        return ans[-1][0]

# %%
# cur_min = (price[i], i)
# ans = [[sum, last_min, last_sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = (prices[0], 0), prices[0]
        for i, price in enumerate(prices):
            print("start" ,i, price, ans)
            if price < cur_min[0]:
                cur_min = (price, i)
                if price < long_min:
                    long_min = price
            else:
                cur_sum = prices[i]-cur_min[0]
                if not ans and cur_sum > 0:
                    ans.append([cur_sum, cur_min[0], cur_sum])
                elif len(ans) < k and ans[-1][1] != cur_min[1]:
                    ans.append([ans[-1][0]+cur_sum, cur_min[0], cur_sum])
                    cur_min = (price, i)
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][2] < cur_sum:
                        ans[j][0] += cur_sum-ans[j][2]
                        ans[j][1] = cur_min[0]
                        ans[j][2] = cur_sum
                if price - long_min > ans[0][0]:
                    ans[0] = [price-long_min, long_min, price-long_min]
            print("stop", ans)
        return ans[-1][0]

# %%
# cur_min = (price[i], i)
# ans = [[sum, last_min, last_sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = (prices[0], 0), prices[0]
        for i, price in enumerate(prices):
            print("start" ,i, price, ans)
            if price < cur_min[0]:
                cur_min = (price, i)
                if price < long_min:
                    long_min = price
            else:
                cur_sum = prices[i]-cur_min[0]
                print(ans, cur_min)
                if not ans and cur_sum > 0:
                    ans.append([cur_sum, cur_min[0], cur_sum])
                elif len(ans) < k and ans[-1][1] != cur_min[1]:
                    ans.append([ans[-1][0]+cur_sum, cur_min[0], cur_sum])
                    cur_min = (price, i)
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][2] < cur_sum:
                        ans[j][0] += cur_sum-ans[j][2]
                        ans[j][1] = cur_min[0]
                        ans[j][2] = cur_sum
                if price - long_min > ans[0][0]:
                    ans[0] = [price-long_min, long_min, price-long_min]
            print("stop", ans)
        return ans[-1][0]

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[prices[0], 0]]
        cur_min, long_min = prices[0], prices[0]
        for i, price in enumerate(prices):
            print(price, ans)
            if price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                cur_sum = price-cur_min
                if len(ans) < k and ans[-1][0] != cur_min:
                    ans.append([price, ans[-1][1]+cur_sum])
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][0] < price:
                        ans[j][1] += (price-ans[j][0])
                        ans[j][0] = price
                    if ans[j-1][1]+cur_sum > ans[j][1]:
                        ans[j] = [price, ans[j-1][1]+cur_sum]
                if price - long_min > ans[0][1]:
                    ans[0] = [long_min, price-long_min]
            print(price, ans)
        return ans[-1][1]

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[prices[0], 0]]
        cur_min, long_min = prices[0], prices[0]
        for i, price in enumerate(prices):
            print(price, ans)
            if price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                cur_sum = price-cur_min
                if len(ans) < k and ans[-1][0] != cur_min:
                    ans.append([price, ans[-1][1]+cur_sum])
                    cur_min = price
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][0] < price:
                        ans[j][1] += (price-ans[j][0])
                        ans[j][0] = price
                    if ans[j-1][1]+cur_sum > ans[j][1]:
                        ans[j] = [price, ans[j-1][1]+cur_sum]
                if price - long_min > ans[0][1]:
                    ans[0] = [long_min, price-long_min]
            print(price, ans)
        return ans[-1][1]

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[prices[0], 0]]
        cur_min, long_min = prices[0], prices[0]
        for i, price in enumerate(prices):
            for item in ans:
                if item[0] > price:
                    item[0] = price
            if price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                if len(ans) < k and ans[-1][0] != cur_min:
                    cur_sum = price-cur_min
                    ans.append([price, ans[-1][1]+cur_sum])
                    cur_min = price
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][0] < price:
                        ans[j][1] += (price-ans[j][0])
                        if ans[j-1][1]+price-ans[j][0] > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+price-ans[j][0]]
                        ans[j][0] = price
                    elif ans[j-1][1]+price-ans[j][0] > ans[j][1]:
                        ans[j] = [price, ans[j-1][1]+price-ans[j][0]]
                if price - long_min > ans[0][1]:
                    ans[0] = [price, price-long_min]
            print(price, ans)
        return ans[-1][1]

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[prices[0], 0]]
        cur_min = prices[0]
        for i, price in enumerate(prices):
            print(price, ans)
            if price < cur_min:
                cur_min = price
            else:
                last_cur_min = cur_min
                cur_sum = price-cur_min
                if len(ans) < k and ans[-1][0] != cur_min:
                    ans.append([price, ans[-1][1]+cur_sum])
                    cur_min = price
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][0] < price:
                        ans[j][1] += (price-ans[j][0])
                        ans[j][0] = price
                    if ans[j-1][1]+cur_sum > ans[j][1]:
                        ans[j] = [price, ans[j-1][1]+cur_sum]
                if price - last_cur_min > ans[0][1]:
                    ans[0] = [price, price-last_cur_min]
            print(price, ans)
        return ans[-1][1]

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[prices[0], 0]]
        cur_min = prices[0]
        for i, price in enumerate(prices):
            print(price, ans)
            if price < cur_min:
                cur_min = price
            else:
                last_min = cur_min
                cur_sum = price-cur_min
                if len(ans) < k and ans[-1][0] != price:
                    ans.append([price, price-last_min])
                    cur_min = price
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][0] < price:
                        ans[j][1] += (price-ans[j][0])
                        ans[j][0] = price
                    if ans[j-1][1]+cur_sum > ans[j][1]:
                        ans[j] = [price, ans[j-1][1]+cur_sum]
                if price - last_min > ans[0][1]:
                    ans[0] = [price, price-last_min]
            print(price, ans)
        return ans[-1][1]

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[prices[0], 0]]
        cur_min = prices[0]
        for i, price in enumerate(prices):
            print(price, ans)
            if price < cur_min:
                cur_min = price
            else:
                last_ans = ans[-1]
                last_min = cur_min
                cur_sum = price-cur_min
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][0] < price:
                        ans[j][1] += (price-ans[j][0])
                        ans[j][0] = price
                    if ans[j-1][1]+cur_sum > ans[j][1]:
                        ans[j] = [price, ans[j-1][1]+cur_sum]
                if price - last_min > ans[0][1]:
                    ans[0] = [price, price-last_min]
                if len(ans) < k and ans[-1][1] < price-last_min+last_ans[1]:
                    ans.append([price, price-last_min+last_ans[1]])
                    cur_min = price
            print(price, ans)
        return ans[-1][1]

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[prices[0], 0]]
        cur_min = prices[0]
        for i, price in enumerate(prices):
            print(price, ans)
            if price < cur_min:
                cur_min = price
            else:
                last_ans = ans[-1]
                last_min = cur_min
                cur_sum = price-cur_min
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][0] < price:
                        ans[j][1] += (price-ans[j][0])
                        ans[j][0] = price
                    if ans[j-1][1]+cur_sum > ans[j][1]:
                        ans[j] = [price, ans[j-1][1]+cur_sum]
                if price - last_min > ans[0][1]:
                    ans[0] = [price, price-last_min]
                if len(ans) < k and last_min != (last_ans[0]-last_ans[1]):
                    if [price, price-last_min+last_ans[1]] != ans[-1]:
                        ans.append([price, price-last_min+last_ans[1]])
                        cur_min = price
            print(price, ans)
        return ans[-1][1]

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min = float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price < cur_min:
                cur_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    last_ans = ans[-1]
                    last_min = cur_min
                    cur_sum = price-cur_min
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - last_min > ans[0][1]:
                        ans[0] = [price, price-last_min]
                    print("blabla", last_min, last_ans, price)
                    if len(ans) < k and last_min != (last_ans[0]-last_ans[1]):
                        if [price, price-last_min+last_ans[1]] != ans[-1]:
                            ans.append([price, price-last_min+last_ans[1]])
                            cur_min = price
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = float("inf"), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            elif price == cur_min:
                continue
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    last_ans = ans[-1]
                    last_min = cur_min
                    cur_sum = price-cur_min
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                    print("blabla", last_min, last_ans, price)
                    if len(ans) < k and last_min != (last_ans[0]-last_ans[1]):
                        if [price, price-last_min+last_ans[1]] != ans[-1]:
                            ans.append([price, price-last_min+last_ans[1]])
                            cur_min = price
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = float("inf"), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price == cur_min:
                continue
            elif price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    last_ans = ans[-1]
                    last_min = cur_min
                    cur_sum = price-cur_min
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                    print("blabla", last_min, last_ans, price)
                    if len(ans) < k and last_min != (last_ans[0]-last_ans[1]):
                        if [price, price-last_min+last_ans[1]] != ans[-1]:
                            ans.append([price, price-last_min+last_ans[1]])
                            cur_min = price
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = float("inf"), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price == cur_min:
                continue
            elif price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    last_ans = ans[-1].copy()
                    last_min = cur_min
                    cur_sum = price-cur_min
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                    print("blabla", last_min, last_ans, price)
                    if len(ans) < k and last_min != (last_ans[0]-last_ans[1]):
                        if [price, price-last_min+last_ans[1]] != ans[-1]:
                            ans.append([price, price-last_min+last_ans[1]])
                            cur_min = price
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = float("inf"), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price == cur_min:
                continue
            elif price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    last_ans = ans[-1].copy()
                    last_min = cur_min
                    cur_sum = price-cur_min
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                    print("blabla", last_min, last_ans, price)
                    if len(ans) < k and last_min != (last_ans[0]-last_ans[1]):
                        if [price, price-last_min+last_ans[1]] != ans[-1]:
                            ans.append([price, price-last_min+last_ans[1]])
                            cur_min = price
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = float("inf"), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price == cur_min:
                continue
            elif price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    last_ans = ans[-1].copy()
                    last_min = cur_min
                    cur_sum = price-cur_min
                    if len(ans) < k and cur_min != (ans[-1][0]-ans[-1][1]):
                        ans.append([price, price-cur_min+ans[-1][1]])
                        cur_min = price                    
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                    print("blabla", last_min, last_ans, price)
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = float("inf"), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price == cur_min:
                continue
            elif price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    last_ans = ans[-1].copy()
                    last_min = cur_min
                    cur_sum = price-cur_min
                    if len(ans) < k and cur_min != (ans[-1][0]-ans[-1][1]):
                        check_append = True
                        check = [price, price-cur_min+ans[-1][1]]
                        if [price, price-cur_min+ans[-1][1]] != ans[-1]:
                            ans.append([price, price-cur_min+ans[-1][1]])
                            cur_min = price                    
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                    if check_append:
                        if ans[-1] != check:
                            ans.append(check)
                    print("blabla", last_min, last_ans, price)
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = float("inf"), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price == cur_min:
                continue
            elif price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    last_ans = ans[-1].copy()
                    last_min = cur_min
                    cur_sum = price-cur_min
                    if len(ans) < k and cur_min != (ans[-1][0]-ans[-1][1]):
                        check_append = True
                        check = [price, price-cur_min+ans[-1][1]]               
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                    if check_append:
                        if ans[-1] != check:
                            ans.append(check)
                            check_append = False
                            cur_min = price
                    print("blabla", last_min, last_ans, price)
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        check_append = False
        ans = []
        cur_min, long_min = float("inf"), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price == cur_min:
                continue
            elif price < cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    last_ans = ans[-1].copy()
                    last_min = cur_min
                    cur_sum = price-cur_min
                    if len(ans) < k and cur_min != (ans[-1][0]-ans[-1][1]):
                        check_append = True
                        check = [price, price-cur_min+ans[-1][1]] 
                        cur_min = price              
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                    if check_append:
                        if ans[-1] != check:
                            ans.append(check)
                            check_append = False
                    print("blabla", last_min, last_ans, price)
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        check_append = False
        ans = []
        cur_min, long_min = (float("inf"), -1), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price == cur_min[0]:
                continue
            elif price < cur_min[0]:
                cur_min = (price, i)
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min[0]])
                    cur_min = (price, i)
                else:
                    last_ans = ans[-1].copy()
                    last_min = cur_min[0]
                    cur_sum = price-cur_min[0]
                    if len(ans) < k and cur_min[0] != (ans[-1][0]-ans[-1][1]):
                        check_append = True
                        check = [price, price-cur_min[0]+ans[-1][1]] 
                        cur_min = (price, i)              
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                    if check_append:
                        if ans[-1] != check:
                            ans.append(check)
                            check_append = False
                    print("blabla", last_min, last_ans, price)
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
# ans = [[cur_min, sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        check_append = False
        ans = []
        cur_min, long_min = float("inf"), float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price <= cur_min:
                cur_min = price
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([price, price-cur_min])
                    cur_min = price
                else:
                    cur_sum = price-cur_min
                    if len(ans) < k and cur_min != (ans[-1][0]-ans[-1][1]):
                        check_append = True
                        check = [price, price-cur_min+ans[-1][1]]               
                    for j in range(len(ans)-1, 0, -1):
                        if ans[j][0] < price:
                            ans[j][1] += (price-ans[j][0])
                            ans[j][0] = price
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                        cur_min = price
                    if check_append:
                        if ans[-1] != check:
                            ans.append(check)
                            check_append = False
                            cur_min = price
                    print("blabla", price)
            print(price, ans)
        return ans[-1][1] if ans else 0

# %%
            if i > 0 and i < len(prices) and (prices[i-1]<prices[i]<prices[i+1] or prices[i-1]>prices[i]>prices[i+1]):
                continue

# %%
# ans = [[cur_min_indx, sum]]
# cur_min ---> index

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        check_append = False
        ans = []
        cur_min, long_min = 0, float("inf")
        for i, price in enumerate(prices):
            print(price, ans)
            if price <= prices[cur_min]:
                cur_min = i
                if price < long_min:
                    long_min = price
            else:
                if not ans:
                    ans.append([i, price-prices[cur_min]])
                    cur_min = i
                else:
                    cur_sum = price-prices[cur_min]
                    if len(ans) < k and cur_min != ans[-1][0]:
                        check_append = True
                        check = [i, price-prices[cur_min]+ans[-1][1]]               
                    for j in range(len(ans)-1, 0, -1):
                        if prices[ans[j][0]] < price:
                            ans[j][1] += (price-prices[ans[j][0]])
                            ans[j][0] = i
                        if ans[j-1][1]+cur_sum > ans[j][1]:
                            ans[j] = [price, ans[j-1][1]+cur_sum]
                    if price - long_min > ans[0][1]:
                        ans[0] = [price, price-long_min]
                        cur_min = i
                    if check_append:
                        if ans[-1] != check:
                            ans.append(check)
                            check_append = False
                            cur_min = i
                    print("blabla", price)
            print(price, ans)
        return ans[-1][1] if ans else 0
