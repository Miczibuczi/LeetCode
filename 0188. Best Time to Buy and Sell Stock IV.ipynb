# %%
# cur_min = (price[i], i)
# ans = [[sum, last_min, last_sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[0, 0, 0]]
        cur_min, long_min = (prices[0], 0), prices[0]
        for i, price in enumerate(prices[1:]):
            if price < cur_min[0]:
                cur_min = (price, i)
                if price < long_min:
                    long_min = price
            else:
                cur_sum = prices[i]-cur_min[0]
                if len(ans) < k and ans[-1][1] != cur_min[1]:
                    ans.append([ans[-1][0]+cur_sum, cur_min, cur_sum])
                for i in range(len(ans)-1, 0, -1):
                    if ans[i][2] < cur_sum:
                        ans[i][0] += cur_sum-ans[i][2]
                        ans[i][1] = cur_min
                        ans[i][2] = cur_sum
                if prices[i] - long_min > ans[0][0]:
                    ans[0] = [prices[i]-long_min, long_min, prices[i]-long_min]
        return ans[-1][0]

# %%
# cur_min = (price[i], i)
# ans = [[sum, last_min, last_sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = [[0, 0, 0]]
        cur_min, long_min = (prices[0], 0), prices[0]
        for i, price in enumerate(prices):
            print("start" ,i, price, ans)
            if price < cur_min[0]:
                cur_min = (price, i)
                if price < long_min:
                    long_min = price
            else:
                cur_sum = prices[i]-cur_min[0]
                if len(ans) < k and ans[-1][1] != cur_min[1]:
                    ans.append([ans[-1][0]+cur_sum, cur_min[0], cur_sum])
                    cur_min = (price, i)
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][2] < cur_sum:
                        ans[j][0] += cur_sum-ans[j][2]
                        ans[j][1] = cur_min[0]
                        ans[j][2] = cur_sum
                if price - long_min > ans[0][0]:
                    ans[0] = [price-long_min, long_min, price-long_min]
            print("stop", ans)
        return ans[-1][0]

# %%
# cur_min = (price[i], i)
# ans = [[sum, last_min, last_sum]]

class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:
        ans = []
        cur_min, long_min = (prices[0], 0), prices[0]
        for i, price in enumerate(prices):
            print("start" ,i, price, ans)
            if price < cur_min[0]:
                cur_min = (price, i)
                if price < long_min:
                    long_min = price
            else:
                cur_sum = prices[i]-cur_min[0]
                if not ans and cur_sum > 0:
                    ans.append([cur_sum, cur_min[0], cur_sum])
                elif len(ans) < k and ans[-1][1] != cur_min[1]:
                    ans.append([ans[-1][0]+cur_sum, cur_min[0], cur_sum])
                    cur_min = (price, i)
                for j in range(len(ans)-1, 0, -1):
                    if ans[j][2] < cur_sum:
                        ans[j][0] += cur_sum-ans[j][2]
                        ans[j][1] = cur_min[0]
                        ans[j][2] = cur_sum
                if price - long_min > ans[0][0]:
                    ans[0] = [price-long_min, long_min, price-long_min]
            print("stop", ans)
        return ans[-1][0]
