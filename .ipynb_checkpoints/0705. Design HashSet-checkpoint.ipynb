# %%
class MyHashSet:

    def __init__(self):    
        self.size = 10**5
        self.arr = [None]*self.size


    def add(self, key: int) -> None:
        index = key%self.size
        while True:
            if not self.arr[index] or self.arr[index] == 0:
                self.arr[index] = key
                break
            elif self.arr[index] == key:
                break
            else:
                index += 1

    def remove(self, key: int) -> None:
        index = key%self.size
        while True:
            if self.arr[index] == key:
                self.arr[index] = 0
                break
            elif not self.arr[index]:
                break
            else:
                index += 1


    def contains(self, key: int) -> bool:
        index = key%self.size
        while True:
            if self.arr[index] == key:
                return True
            elif self.arr[index] is None:
                return False
            else:
                index += 1


# Your MyHashSet object will be instantiated and called as such:
# obj = MyHashSet()
# obj.add(key)
# obj.remove(key)
# param_3 = obj.contains(key)
